# %%
#calculate the area of a circle
radius=5.5
area =3.14* radius**2
print(area)
# Out:
# 94.985

# %%
# Calculate the average of 3.14, 2.718, 1.618, 0.577
a=(3.14,2.718,1.618,0.577)
b=sum(a)/len(a)
print(b)
# Out:
# 2.01325

# %%
#Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)
farhen_heat=98.6
celcius_heat=5/9 * farhen_heat - 32
print(celcius_heat)
# Out:
# 22.77777777777778

# %%
#Calculate compound interest on $1000 at 5.5% for 3 years a= p(1+r)**t
a= 1000 * (1+ 0.055)**3
print(a)
# Out:
# 1174.2413749999998

# %%
#Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2
a=3.5
b=4.2
hypo= (a**2 + b**2)**0.5
print(hypo)
# Out:
# 5.4671747731346585

# %%
#5: Calculate the volume of a sphere with radius 7.8
radius = 7.8
volume= 4/3 * 3.14 * 7.8**3
print(volume)
# Out:
# 1986.7910399999998

# %%
#Question 6: Round 3.14159 to 3 decimal places
num = 3.14159
b= round(num,3)
print(b)
# Out:
# 3.142

# %%
#Question 7: Calculate the percentage: 45 out of 67
obtain_marks= 45
total_marks= 67
per=obtain_marks/total_marks* 100
print((per))
# Out:
# 67.16417910447761

# %%
#Question 8: Find the square root of 23.456
num= 23.456
square_root= num ** 0.5
print(square_root)

# %%
#Question 9: Calculate simple interest: Principal=2500, Rate=6.5%, Time=2.5 years")
p= 2500
r= 6.5
t= 2.5
intrest= p * (1+ r/100)**t
print(intrest)

# %%
#Question 10: Convert 45.7 degrees to radians"
deg = 45.7
raidains= 45.7 * 3.14/180
print(raidains)
